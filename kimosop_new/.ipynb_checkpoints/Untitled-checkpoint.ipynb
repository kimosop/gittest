# %% [markdown]
# # Intro to Python

# %% [markdown]
# ## Python as a Calculator

# %%
#addition
1+1
# Out:
# 2

# %%
#Subtraction
10-2
# Out:
# 8

# %%
#Division
687/56
# Out:
# 12.267857142857142

# %%
#Power
5**2
# Out:
# 25

# %%
# floor division discards the fractional part
17//2
# Out:
# 8

# %%
# the % operator returns the remainder of the division
20%3
# Out:
# 2

# %%
x=6

# %%
x
# Out:
# 6

# %%
Distance=100
Time=40
y=Time/60
Speed=Distance/y

# %%
Speed
# Out:
# 150.0

# %% [markdown]
# # Strings

# %%
a= "Python"
a
# Out:
# 'Python'

# %%
a[0]
# Out:
# 'P'

# %%
a[3]
# Out:
# 'h'

# %%
a[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-84c1e027215d> in <module>
# ----> 1 a[6]
#
# IndexError: string index out of range

# %%
#Display index 0 to 3
a[0:3]
# Out:
# 'Pyt'

# %%
#Skipping range
a[0:5:2]
# Out:
# 'Pto'

# %%
a[4]+a[1]
# Out:
# 'oy'

# %%
a[0]+a[4]+a[2]
# Out:
# 'Pot'

# %%
"big" *5
# Out:
# 'bigbigbigbigbig'

# %%
try:
    age = int(input("Please Enter Your age:"))
    print("I see that you are %d years old." % age)
except ValueError:
    print("Hey, that wasn't a number")
# Out:
# Please Enter Your age:50
# I see that you are 50 years old.

# %%
age
# Out:
# 50

# %%
c = ("Eric Wanyama")
c
# Out:
# 'Eric Wanyama'

# %%
d = "Victor Kimosop"
d
# Out:
# 'Victor Kimosop'

# %%
d+c
# Out:
# 'Victor KimosopEric Wanyama'

# %%
d, " "+ c
# Out:
# ('Victor Kimosop', ' Eric Wanyama')

# %%
print (c)
# Out:
# Eric Wanyama

# %% [markdown]
# # Control Statements

# %%
count = 0
while (count <9):
    print("The count is", count)
    count = count + 1
print("Good Bye!")
# Out:
# The count is 0
# The count is 1
# The count is 2
# The count is 3
# The count is 4
# The count is 5
# The count is 6
# The count is 7
# The count is 8
# Good Bye!

# %%
count = 0
while (count <9):
    print("The count is", count)
    count = count + 1
print ("hey")
print("Good Bye!")
# Out:
# The count is 0
# The count is 1
# The count is 2
# The count is 3
# The count is 4
# The count is 5
# The count is 6
# The count is 7
# The count is 8
# hey
# Good Bye!
