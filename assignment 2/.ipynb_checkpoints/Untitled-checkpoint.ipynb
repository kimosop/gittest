# %% [markdown]
# # assignment 2

# %%
while True:
    try:
        x = user_input = int(input("Please enter a number x: "))
    except ValueError:
        print("Please input a valid number")
        continue
    else:
        break
        
while True:
    try:
        y = user_input = int(input("Please enter a number y: "))
    except ValueError:
        print("Please input a valid number")
        continue
    else:
        break

power = x**y
print('The result of %d raise to %d is: %d ' %(x,y,power))
import math
print(math.log(x, 10))
# Out:
# Please enter a number x: e
# Please input a valid number

# %%
x = int(input("Enter an integer x: "))
y = int(input("Enter another integer y: "))
power = x**y
print('The result is ', power,)
import math
print( math.log(x, 10))
# Out:
# Enter an integer x: 5
# Enter another integer y: 5
# The result is  3125
# 0.6989700043360187

# %%
a = 200
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# a is greater than b

# %%
adj = ["red", "big", "tasty"]
fruits = ["apple", "banana", "cherry"]
print(adj, fruits)
# Out:
# ['red', 'big', 'tasty'] ['apple', 'banana', 'cherry']

# %%
adj = ["red", "big", "tasty"]
fruits = ["apple", "banana", "cherry"]
p = ["apple", "banana", "cherry"]
for x in adj:
    for y in fruits:
        print(x,y)
# Out:
# red apple
# red banana
# red cherry
# big apple
# big banana
# big cherry
# tasty apple
# tasty banana
# tasty cherry
