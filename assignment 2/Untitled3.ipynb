# %% [markdown]
# # 7th Feb

# %%
import pandas as pd

# %%
# import data
df=pd.read_csv("..\..\Downloads\Government_Appointments_to_State_Parastatal_Agencies.csv")
df.head()
# Out:
#    GAZETTE_NOTICE_NO_                    Year  \
# 0                2827  01/01/2015 12:00:00 AM
# 1                2828  01/01/2015 12:00:00 AM
# 2                2829  01/01/2015 12:00:00 AM
# 3                2829  01/01/2015 12:00:00 AM
# 4                2829  01/01/2015 12:00:00 AM
#
#                                         ACT    Cap      Persons_Appointed_  \
# 0                The State Corporations Act  446.0          Gershom Otachi
# 1                The State Corporations Act  446.0             Sammy Choge
# 2  Agricultural Development Corporation Act  444.0              Musa Sirma
# 3  Agricultural Development Corporation Act  444.0    Susan Akinyi Wakiaga
# 4  Agricultural Development Corporation Act  444.0  Joseph Miriti Mwereria
#
#              Position_         Date_Appointed_              Start_Date  \
# 0          Chairperson  04/17/2015 12:00:00 AM  05/20/2015 12:00:00 AM
# 1          Chairperson  04/17/2015 12:00:00 AM  04/17/2015 12:00:00 AM
# ...

# %%
df.isna().sum()
# Out:
# GAZETTE_NOTICE_NO_            0
# Year                          0
# ACT                           0
# Cap                         166
# Persons_Appointed_            1
# Position_                     0
# Date_Appointed_              48
# Start_Date                   20
# End_Date                    284
# Person_Appointing_            0
# Apointers_Position            0
# Ministry                     44
# Parastatle_Appointed_to_      5
# Duration_Months              19
# Status                        0
# Gender                       23
# Original_GN                 285
# Original_GN_Year            305
# OBJECTID                      0
# dtype: int64

# %%
df.columns #shows all columns
# Out:
# Index(['GAZETTE_NOTICE_NO_', 'Year', 'ACT', 'Cap', 'Persons_Appointed_',
#        'Position_', 'Date_Appointed_', 'Start_Date', 'End_Date',
#        'Person_Appointing_', 'Apointers_Position', 'Ministry',
#        'Parastatle_Appointed_to_', 'Duration_Months', 'Status', 'Gender',
#        'Original_GN', 'Original_GN_Year', 'OBJECTID'],
#       dtype='object')

# %%
df.describe()
# Out:
#        GAZETTE_NOTICE_NO_         Cap  Duration_Months  Original_GN  \
# count          305.000000  139.000000       286.000000      20.0000
# mean          2886.770492  432.705036        35.769231    3523.8000
# std             28.617827   62.181997         2.302378    3932.9613
# min           2827.000000  117.000000        10.000000       5.0000
# 25%           2868.000000  441.000000        36.000000    2488.7500
# 50%           2889.000000  446.000000        36.000000    2679.0000
# 75%           2913.000000  447.500000        36.000000    2896.0000
# max           2929.000000  517.000000        36.000000   15765.0000
#
#        Original_GN_Year    OBJECTID
# count               0.0  305.000000
# mean                NaN  152.000000
# std                 NaN   88.190136
# min                 NaN    0.000000
# 25%                 NaN   76.000000
# 50%                 NaN  152.000000
# 75%                 NaN  228.000000
# max                 NaN  304.000000

# %%
df.describe(include='all')
# Out:
#         GAZETTE_NOTICE_NO_                    Year                       ACT  \
# count           305.000000                     305                       305
# unique                 NaN                       1                        60
# top                    NaN  01/01/2015 12:00:00 AM  Water Act (No. 8 Of2002)
# freq                   NaN                     305                        54
# mean           2886.770492                     NaN                       NaN
# std              28.617827                     NaN                       NaN
# min            2827.000000                     NaN                       NaN
# 25%            2868.000000                     NaN                       NaN
# 50%            2889.000000                     NaN                       NaN
# 75%            2913.000000                     NaN                       NaN
# max            2929.000000                     NaN                       NaN
#
# ...

# %%
df.dtypes
# Out:
# GAZETTE_NOTICE_NO_            int64
# Year                         object
# ACT                          object
# Cap                         float64
# Persons_Appointed_           object
# Position_                    object
# Date_Appointed_              object
# Start_Date                   object
# End_Date                     object
# Person_Appointing_           object
# Apointers_Position           object
# Ministry                     object
# Parastatle_Appointed_to_     object
# Duration_Months             float64
# Status                       object
# Gender                       object
# Original_GN                 float64
# Original_GN_Year            float64
# OBJECTID                      int64
# dtype: object

# %%
df['Start_Date'] to

# %%
df['Gender'] = df['Gender'].astype('category')
df['Gender'].dtype
# Out:
# CategoricalDtype(categories=['M', 'f', 'm'], ordered=False)

# %%
dates = ['Date_Appointed_', 'Start_Date', 'End_Date', 'Year']
for Date
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-276afa67d29c> in <module>
# ----> 1 df['Start_Date'] = df['Start_Date'].astype('Date')
#       2 df['Gender'].dtype
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
# ...

# %%
df.rename(columns = {'M':'m'}, inplace = True)
df['M']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'M'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-3c2789b77070> in <module>
# ...

# %%
df.apply(lambda x: x.value_counts()).T.stack()
# Out:
# C:\Users\vchepkoit\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\api.py:107: RuntimeWarning: '<' not supported between instances of 'int' and 'str', sort order is undefined for incomparable objects
#   result = result.union(other)
# C:\Users\vchepkoit\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:7397: RuntimeWarning: '<' not supported between instances of 'int' and 'str', sort order is undefined for incomparable objects
#   index = _union_indexes(indexes)
# GAZETTE_NOTICE_NO_  2829    11.0
#                     2870    10.0
#                     2920     8.0
#                     2914     7.0
#                     2927     7.0
#                     2890     7.0
#                     2923     7.0
#                     2922     7.0
#                     2928     7.0
#                     2929     6.0
#                     2894     6.0
#                     2888     6.0
#                     2887     6.0
# ...

# %%
df.groupby('Position_').count()
# Out:
#                                    GAZETTE_NOTICE_NO_  Year  ACT  Cap  \
# Position_
# Board of Directors Chairperson                      4     4    4    4
# Board of Trustees Chairperson                       2     2    2    2
# Chairperson                                        36    36   36   13
# Commisioners                                        4     4    4    0
# Council Members                                    10    10   10   10
# Director                                            2     2    2    2
# Member of the Board                               227   227  227  102
# Member of the Board of Trustees                     1     1    1    0
# Members of the Advisory Board                       5     5    5    0
# Members of the Board of Directors                   6     6    6    6
# Members of the Oversight  Board                     1     1    1    0
# Non-Executive Chairperson                           1     1    1    0
# ...

# %%
df.('Position_').valuecount()
# Out:
#   File "<ipython-input-37-10f21ed775c7>", line 1
#     df.('Position_').valuecount()
#        ^
# SyntaxError: invalid syntax

# %%
df.describe(include='all')
# Out:
#         GAZETTE_NOTICE_NO_                    Year                       ACT  \
# count           305.000000                     305                       305
# unique                 NaN                       1                        60
# top                    NaN  01/01/2015 12:00:00 AM  Water Act (No. 8 Of2002)
# freq                   NaN                     305                        54
# mean           2886.770492                     NaN                       NaN
# std              28.617827                     NaN                       NaN
# min            2827.000000                     NaN                       NaN
# 25%            2868.000000                     NaN                       NaN
# 50%            2889.000000                     NaN                       NaN
# 75%            2913.000000                     NaN                       NaN
# max            2929.000000                     NaN                       NaN
#
# ...

# %%
df['Date_Appointed_'].min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     127                 else:
# --> 128                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     129             except Exception:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\nanops.py in reduction(values, axis, skipna)
#     506         else:
# --> 507             result = getattr(values, meth)(axis)
#     508
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\_methods.py in _amin(a, axis, out, keepdims, initial)
#      31           initial=_NoValue):
# ---> 32     return umr_minimum(a, axis, None, out, keepdims, initial)
#      33
#
# TypeError: '<=' not supported between instances of 'str' and 'float'
#
# ...

# %%
df['Duration_idle'] = df['Date_Appointed_'] - df['Start_Date']
df.sample(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1011         try:
# -> 1012             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1013         except TypeError:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ...
