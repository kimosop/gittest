# %% [markdown]
# # Horticultural Exports

# %%
import pandas as pd

# %%
# import data
df=pd.read_csv("..\..\Downloads\Distribution_of_Donor_and_GOK_Funded_Projects_2013_to_2015.csv")
df.head()
# Out:
#    objectid    projectid    epgeoname         y          x    ward  \
# 0         1  2013/054253  Unspecified -4.593836  39.136688   VANGA
# 1         2  2013/054557  Unspecified -4.437633  39.513272     NaN
# 2         3  2014/054836  Unspecified -4.437633  39.513272     NaN
# 3         4  2014/055098  Unspecified -4.437633  39.513272     NaN
# 4         5  2012/053881  Unspecified -4.341045  39.553797  UKUNDA
#
#   constituency county  project_cost_yearly_breakdown__  \
# 0   LUNGALUNGA  KWALE                              NaN
# 1    MSAMBWENI  KWALE                     9.333333e+08
# 2    MSAMBWENI  KWALE                     1.432821e+09
# 3    MSAMBWENI  KWALE                              NaN
# 4    MSAMBWENI  KWALE                     1.640000e+10
#
#    total_project_cost__kes_          ...            \
# 0                       NaN          ...
# 1              1.400000e+09          ...
# 2              4.298464e+09          ...
# 3                       NaN          ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 6 columns):
# TYPE_OF_COMMODITY          1800 non-null object
# COMMODITY                  1800 non-null object
# KGs                        1800 non-null float64
# Value_of_Goods_Exported    1788 non-null object
# DATE                       1800 non-null object
# OBJECTID                   1800 non-null int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 84.5+ KB

# %%
df.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-ea942bf769f0> in <module>
# ----> 1 df.columns()
#
# TypeError: 'Index' object is not callable

# %%
df.describe()
# Out:
#                 KGs    OBJECTID
# count  1.800000e+03  1800.00000
# mean   1.322300e+05   899.50000
# std    8.114427e+05   519.75956
# min    0.000000e+00     0.00000
# 25%    0.000000e+00   449.75000
# 50%    5.710000e+02   899.50000
# 75%    7.014528e+03  1349.25000
# max    1.104919e+07  1799.00000

# %%
df.isna().sum()
# Out:
# TYPE_OF_COMMODITY           0
# COMMODITY                   0
# KGs                         0
# Value_of_Goods_Exported    12
# DATE                        0
# OBJECTID                    0
# dtype: int64
