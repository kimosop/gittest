# %% [markdown]
# # Functions

# %%
a = "Python"

# %%
len(a)
# Out:
# 6

# %%
b = 40.5647

# %%
print(b)
# Out:
# 40.5647

# %%
round(b)
# Out:
# 41

# %%
tuple(a)
# Out:
# ('P', 'y', 't', 'h', 'o', 'n')

# %%
c = (23,65,34,87)

# %%
max(c)
# Out:
# 87

# %%
min(c)
# Out:
# 23

# %%
str(b)
# Out:
# '40.5647'

# %%
range(10)
# Out:
# range(0, 10)

# %%
def hello():
    print("Hi, there?")

# %%
hello()
# Out:
# Hi, there?

# %%
user_input = int(input("Please enter a number x: "))

# %%
x = int(input("Enter a number: "))
y = int(input("Enter a second number: "))
print(x + y)
